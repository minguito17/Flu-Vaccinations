# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting klib
#   Downloading klib-1.1.2-py3-none-any.whl (22 kB)
# Requirement already satisfied: plotly<6.0.0,>=5.2.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from klib->-r ./requirements.txt (line 1)) (5.10.0)
# Requirement already satisfied: scipy<2.0.0,>=1.1.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from klib->-r ./requirements.txt (line 1)) (1.9.3)
# Requirement already satisfied: seaborn>=0.11.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from klib->-r ./requirements.txt (line 1)) (0.13.2)
# Requirement already satisfied: Jinja2<4.0.0,>=3.0.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from klib->-r ./requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: numpy<2.0.0,>=1.16.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from klib->-r ./requirements.txt (line 1)) (1.23.4)
# Collecting screeninfo<0.9.0,>=0.8.1
#   Downloading screeninfo-0.8.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: pandas<3.0,>=1.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from klib->-r ./requirements.txt (line 1)) (2.1.4)
# Requirement already satisfied: matplotlib<4.0.0,>=3.0.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from klib->-r ./requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from Jinja2<4.0.0,>=3.0.3->klib->-r ./requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.0.3->klib->-r ./requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.0.3->klib->-r ./requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.0.3->klib->-r ./requirements.txt (line 1)) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.0.3->klib->-r ./requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.0.3->klib->-r ./requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.0.3->klib->-r ./requirements.txt (line 1)) (9.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.0.3->klib->-r ./requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.0.3->klib->-r ./requirements.txt (line 1)) (4.37.4)
# Requirement already satisfied: pytz>=2020.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas<3.0,>=1.2->klib->-r ./requirements.txt (line 1)) (2022.5)
# Requirement already satisfied: tzdata>=2022.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas<3.0,>=1.2->klib->-r ./requirements.txt (line 1)) (2022.5)
# Requirement already satisfied: tenacity>=6.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from plotly<6.0.0,>=5.2.2->klib->-r ./requirements.txt (line 1)) (8.1.0)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.0.3->klib->-r ./requirements.txt (line 1)) (1.16.0)
# Installing collected packages: screeninfo, klib
# Successfully installed klib-1.1.2 screeninfo-0.8.1
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
